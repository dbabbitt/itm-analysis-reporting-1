# %%
# %pprint
import sys
if ('../py' not in sys.path): sys.path.insert(1, '../py')
# Out:
# Pretty printing has been turned OFF

# %%
from FRVRS import nu, fu
from pandas import DataFrame
from itertools import product
from pysan.statistics import get_turbulence
from pysan import get_entropy, get_complexity

# %%
# load data frames
data_frames_dict = nu.load_data_frames(frvrs_logs_df='frvrs_logs_df', distance_delta_df='distance_delta_df')
frvrs_logs_df = data_frames_dict['frvrs_logs_df']
print(frvrs_logs_df.shape) # (829116, 120)
distance_delta_df = data_frames_dict['distance_delta_df']
print(distance_delta_df.shape) # (873, 15)
# Out:
# Attempting to load /mnt/c/Users/DaveBabbitt/Documents/GitHub/itm-analysis-reporting/saves/pkl/frvrs_logs_df.pkl.
# Attempting to load /mnt/c/Users/DaveBabbitt/Documents/GitHub/itm-analysis-reporting/saves/pkl/distance_delta_df.pkl.
# (829116, 120)
# (873, 15)

# %% [markdown]
# # Create a DataFrame of all the Scene Stats

# %%
def add_scene_columns_to_row(scene_df, row_dict):
    row_dict['first_engagement'] = fu.get_first_engagement(scene_df)
    row_dict['first_treatment'] = fu.get_first_treatment(scene_df)
    row_dict['injury_correctly_treated_count'] = fu.get_injury_correctly_treated_count(scene_df)
    row_dict['injury_not_treated_count'] = fu.get_injury_not_treated_count(scene_df)
    row_dict['injury_treated_count'] = fu.get_injury_treatments_count(scene_df)
    row_dict['injury_wrongly_treated_count'] = fu.get_injury_wrongly_treated_count(scene_df)
    row_dict['is_a_one_triage_file'] = fu.get_is_a_one_triage_file(scene_df)
    row_dict['is_scene_aborted'] = fu.get_is_scene_aborted(scene_df)
    row_dict['last_engagement'] = fu.get_last_engagement(scene_df)
    row_dict['logger_version'] = fu.get_logger_version(scene_df)
    row_dict['measure_of_right_ordering'] = fu.get_measure_of_right_ordering(scene_df)
    row_dict['patient_count'] = fu.get_patient_count(scene_df)
    row_dict['percent_hemorrhage_controlled'] = fu.get_percent_hemorrhage_controlled(scene_df)
    row_dict['pulse_taken_count'] = fu.get_pulse_taken_count(scene_df)
    row_dict['scene_end'] = fu.get_scene_end(scene_df)
    row_dict['scene_start'] = fu.get_scene_start(scene_df)
    row_dict['scene_type'] = fu.get_scene_type(scene_df)
    row_dict['stills_value'] = fu.get_stills_value(scene_df)
    row_dict['teleport_count'] = fu.get_teleport_count(scene_df)
    row_dict['time_to_last_hemorrhage_controlled'] = fu.get_time_to_last_hemorrhage_controlled(scene_df)
    row_dict['total_actions'] = fu.get_total_actions_count(scene_df)
    row_dict['triage_time'] = fu.get_triage_time(scene_df)
    row_dict['voice_capture_count'] = fu.get_voice_capture_count(scene_df)
    row_dict['walk_command_count'] = fu.get_walk_command_count(scene_df)
    row_dict['walk_value'] = fu.get_walk_value(scene_df)
    row_dict['walkers_value'] = fu.get_walkers_value(scene_df)
    row_dict['wave_command_count'] = fu.get_wave_command_count(scene_df)
    row_dict['wave_value'] = fu.get_wave_value(scene_df)

    return row_dict

# %%
if nu.pickle_exists('scene_stats_df'): scene_stats_df = nu.load_object('scene_stats_df')
else:
    
    # Get the combo alphabet list
    combos_alphabet = sorted(set([sequence_tuple[0] + '-' + sequence_tuple[1] for sequence_tuple in product(
        fu.patient_sort_order, fu.injury_severity_order
    )]))
    
    rows_list = []
    engagment_columns_list = ['patient_id', 'engagement_start', 'location_tuple', 'patient_sort', 'predicted_priority', 'injury_severity']
    for (session_uuid, scene_id), idx_df in distance_delta_df.groupby(fu.scene_groupby_columns):
        row_dict = list(idx_df.T.to_dict().values())[0]
        
        # Get the whole scene history
        mask_series = True
        for cn in fu.scene_groupby_columns: mask_series &= (frvrs_logs_df[cn] == eval(cn))
        scene_df = frvrs_logs_df[mask_series]
        
        # Get the engagement sequence and the stats from that
        actual_engagement_order = fu.get_actual_engagement_order(scene_df, verbose=False)
        if actual_engagement_order:
            df = DataFrame(actual_engagement_order, columns=engagment_columns_list)
            patient_sorts_list = df.apply(lambda row_series: row_series.patient_sort, axis='columns').tolist()
            patient_sorts_sequence, patient_sorts_string_to_integer_map = nu.convert_strings_to_integers(
                patient_sorts_list, alphabet_list=fu.patient_sort_order
            )
            injury_severitys_list = df.apply(lambda row_series: row_series.injury_severity, axis='columns').tolist()
            injury_severitys_sequence, injury_severitys_string_to_integer_map = nu.convert_strings_to_integers(
                injury_severitys_list, alphabet_list=fu.injury_severity_order
            )
            combos_list = [str(patient_sort) + '-' + str(injury_severity) for patient_sort, injury_severity in zip(
                patient_sorts_list, injury_severitys_list
            )]
            combos_sequence, combos_string_to_integer_map = nu.convert_strings_to_integers(combos_list, alphabet_list=combos_alphabet)
            
            # Replace negative values with 9s to maintain character width
            patient_sorts_sequence[patient_sorts_sequence < 0] = 9
            injury_severitys_sequence[injury_severitys_sequence < 0] = 9
            combos_sequence[combos_sequence < 0] = 9
            
            for fn in [get_turbulence, get_entropy, get_complexity]:
                function_name = fn.__name__
                for cn in ['patient_sort', 'injury_severity', 'combo']:
                    dictionary_key = function_name.replace('get', cn)
                    variable_name = f'{cn}s_sequence'
                    try:
                        dictionary_value = fn(list(eval(variable_name)))
                        row_dict[dictionary_key] = dictionary_value
                    except: continue
        
        row_dict = add_scene_columns_to_row(scene_df, row_dict)
        rows_list.append(row_dict)
    scene_stats_df = DataFrame(rows_list)
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)
print(scene_stats_df.shape) # (880, 59)
# Out:
# (880, 59)

# %%
# Merge file stats with the scene stats
if 'encounter_layout' not in scene_stats_df.columns:
    data_frames_dict = nu.load_data_frames(file_stats_df='file_stats_df')
    file_stats_df = data_frames_dict['file_stats_df']
    on_list = list(set(file_stats_df.columns).intersection(set(scene_stats_df.columns)))
    scene_stats_df = scene_stats_df.merge(file_stats_df, how='left', on=on_list).drop_duplicates().reset_index(drop=True)
    mask_series = scene_stats_df.responder_type.isnull()
    scene_stats_df.loc[mask_series, 'responder_type'] = 'Unknown'
    mask_series = scene_stats_df.site_name.isnull()
    scene_stats_df.loc[mask_series, 'site_name'] = 'Unknown'
    mask_series = scene_stats_df.encounter_layout.isnull()
    scene_stats_df.loc[mask_series, 'encounter_layout'] = 'Unknown'
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)

# %%
# Fix the null file dates
mask_series = scene_stats_df.session_file_date.isnull()
if mask_series.any():
    print(f'I have {mask_series.sum()} scenes in my stats data frame without file dates.')
    data_frames_dict = nu.load_data_frames(frvrs_logs_df='frvrs_logs_df')
    frvrs_logs_df = data_frames_dict['frvrs_logs_df']
    for session_uuid, idx_df in scene_stats_df[mask_series].groupby('session_uuid'):
        
        # Get the whole session history
        mask_series = (frvrs_logs_df.session_uuid == session_uuid)
        session_df = frvrs_logs_df[mask_series]
        
        session_file_date = session_df.event_time.min().date()
        scene_stats_df.loc[idx_df.index, 'session_file_date'] = session_file_date
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)
    mask_series = scene_stats_df.session_file_date.isnull()
    print(f'I now have {mask_series.sum()} scenes in my stats data frame without file dates.')

# %%
# Convert the session file date to a datetime64[ns]
if (str(scene_stats_df.session_file_date.dtypes) != 'datetime64[ns]'):
    from pandas import to_datetime
    scene_stats_df.session_file_date = to_datetime(scene_stats_df.session_file_date, infer_datetime_format=True)
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)

# %%
# Check if all the patient IDs in any run are some variant of Mike and designate those runs as "Orientation"
new_column_name = 'scene_type'
if (new_column_name not in scene_stats_df.columns): scene_stats_df[new_column_name] = 'Triage'
column_value = 'Orientation'
if (column_value not in scene_stats_df.scene_type.unique()):
    
    # Filter out those files from the dataset and mark them
    base_mask_series = frvrs_logs_df.groupby(fu.scene_groupby_columns).patient_id.transform(lambda srs: all(
        srs.str.lower().str.contains('mike')
    ))
    session_uuids_list = frvrs_logs_df[base_mask_series].session_uuid.unique().tolist()
    mask_series = scene_stats_df.session_uuid.isin(session_uuids_list)
    scene_stats_df.loc[mask_series, new_column_name] = column_value
    
    # Store the results and show the new data frame shape
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)
    print(scene_stats_df.shape) # (880, 59)
    
display(scene_stats_df.groupby(new_column_name).size().to_frame().rename(columns={0: 'record_count'}))
# Out:
#              record_count
# scene_type
# Orientation           395
# Triage                485

# %%
# Any runs longer than that 16 minutes are probably an instance
# of someone taking off the headset and setting it on the ground.
# 1 second = 1,000 milliseconds; 1 minute = 60 seconds
new_column_name = 'is_scene_aborted'
# if (new_column_name in frvrs_logs_df.columns): frvrs_logs_df = frvrs_logs_df.drop(columns=new_column_name)
if (new_column_name not in scene_stats_df.columns):
    scene_stats_df[new_column_name] = False
    for (session_uuid, scene_id), scene_df in frvrs_logs_df.groupby(fu.scene_groupby_columns):
        mask_series = True
        for cn in fu.scene_groupby_columns: mask_series &= (scene_stats_df[cn] == eval(cn))
        scene_stats_df.loc[mask_series, new_column_name] = fu.get_is_scene_aborted(scene_df)
    
    # Store the results and show the new data frame shape
    nu.store_objects(scene_stats_df=scene_stats_df)
    nu.save_data_frames(scene_stats_df=scene_stats_df)
    
    print(scene_stats_df.shape) # (880, 59)
display(scene_stats_df.groupby(new_column_name).size().to_frame().rename(columns={0: 'record_count'}))
# Out:
#                   record_count
# is_scene_aborted
# False                      880

# %%
scene_stats_df.sample(8).T
# Out:
#                                                                                   527  \
# session_uuid                                     992d4672-7993-44ba-890c-0d8605ccefdd
# scene_id                                                                            1
# last_still_engagement                                                        151731.0
# actual_engagement_distance                                                  35.761345
# ideal_engagement_distance                                                   40.741238
# measure_of_ideal_ordering                                                    0.611431
# distracted_engagement_distance                                               29.55848
# measure_of_distracted_ordering                                               0.033897
# measure_of_right_ordering                                                    0.905641
# actual_ideal_delta                                                          -4.979893
# actual_distracted_delta                                                      6.202865
# adherence_to_salt                                                               False
# has_patient_in_agony                                                             True
# patient_count                                                                      11
# cluster_label                                                                       0
# patient_sort_turbulence                                                      9.869631
# injury_severity_turbulence                                                   9.328241
# combo_turbulence                                                             9.659104
# patient_sort_entropy                                                         0.971307
# injury_severity_entropy                                                      0.992215
# combo_entropy                                                                0.933817
# patient_sort_complexity                                                      0.728336
# injury_severity_complexity                                                   0.736133
# combo_complexity                                                             0.686676
# first_engagement                                                             301980.0
# first_treatment                                                              355537.0
# injury_correctly_treated_count                                                      8
# injury_not_treated_count                                                            0
# injury_wrongly_treated_count                                                        1
# is_a_one_triage_file                                                             True
# is_scene_aborted                                                                False
# last_engagement                                                              655409.0
# logger_version                                                                    1.0
# percent_hemorrhage_controlled                                               44.444444
# pulse_taken_count                                                                  14
# scene_end                                                                      667538
# scene_start                                                                    263586
# scene_type                                                                     Triage
# stills_value                                                                        0
# teleport_count                                                                     27
# time_to_last_hemorrhage_controlled                                             314612
# total_actions                                                                     797
# triage_time                                                                    403952
# voice_capture_count                                                                11
# walk_command_count                                                                  1
# walk_value                                                                          1
# walkers_value                                                                       0
# wave_command_count                                                                  1
# wave_value                                                                          1
# is_cluster2                                                                     False
# injury_treatments_count                                                           9.0
# file_name                           v.1.0/clean-992d4672-7993-44ba-890c-0d8605ccef...
# session_file_date                                                 2023-05-09 09:38:00
# responder_name                                                                Chris D
# responder_type                                                              Paramedic
# site_name                                                                   Plain Twp
# encounter_layout                                                             First 11
# session_file_week                                                              202319
# session_file_week_category                                                       12.0
#
#                                                                                   508  \
# session_uuid                                     9179223d-a6e0-4612-8200-40f30d05c11e
# scene_id                                                                            1
# last_still_engagement                                                        104407.0
# actual_engagement_distance                                                  36.702121
# ideal_engagement_distance                                                   41.205982
# measure_of_ideal_ordering                                                     0.42606
# distracted_engagement_distance                                              29.670197
# measure_of_distracted_ordering                                               0.224809
# measure_of_right_ordering                                                     0.59524
# actual_ideal_delta                                                          -4.503861
# actual_distracted_delta                                                      7.031924
# adherence_to_salt                                                               False
# has_patient_in_agony                                                             True
# patient_count                                                                      11
# cluster_label                                                                       0
# patient_sort_turbulence                                                     10.096862
# injury_severity_turbulence                                                   9.889357
# combo_turbulence                                                            10.069929
# patient_sort_entropy                                                         0.971307
# injury_severity_entropy                                                      0.992215
# combo_entropy                                                                0.933817
# patient_sort_complexity                                                      0.594684
# injury_severity_complexity                                                   0.736133
# combo_complexity                                                             0.635739
# first_engagement                                                             253555.0
# first_treatment                                                              263046.0
# injury_correctly_treated_count                                                      8
# injury_not_treated_count                                                            0
# injury_wrongly_treated_count                                                        0
# is_a_one_triage_file                                                             True
# is_scene_aborted                                                                False
# last_engagement                                                              486986.0
# logger_version                                                                    1.0
# percent_hemorrhage_controlled                                               55.555556
# pulse_taken_count                                                                   9
# scene_end                                                                      507798
# scene_start                                                                    202659
# scene_type                                                                     Triage
# stills_value                                                                        1
# teleport_count                                                                     31
# time_to_last_hemorrhage_controlled                                             225603
# total_actions                                                                     462
# triage_time                                                                    305139
# voice_capture_count                                                                62
# walk_command_count                                                                  4
# walk_value                                                                          1
# walkers_value                                                                       0
# wave_command_count                                                                  6
# wave_value                                                                          1
# is_cluster2                                                                     False
# injury_treatments_count                                                           8.0
# file_name                           v.1.0/clean-9179223d-a6e0-4612-8200-40f30d05c1...
# session_file_date                                                 2023-05-31 09:11:00
# responder_name                                                                James N
# responder_type                                                              Paramedic
# site_name                                                                Franklin Twp
# encounter_layout                                                             First 11
# session_file_week                                                              202322
# session_file_week_category                                                        4.0
#
#                                                                      123  \
# session_uuid                        206da802-d38f-4f3a-98e3-44f99481479d
# scene_id                                                               1
# last_still_engagement                                           149250.0
# actual_engagement_distance                                     38.803266
# ideal_engagement_distance                                      41.363188
# measure_of_ideal_ordering                                       0.516149
# distracted_engagement_distance                                 31.403508
# measure_of_distracted_ordering                                  0.317356
# measure_of_right_ordering                                       0.813972
# actual_ideal_delta                                             -2.559922
# actual_distracted_delta                                         7.399758
# adherence_to_salt                                                  False
# has_patient_in_agony                                                True
# patient_count                                                         11
# cluster_label                                                          0
# patient_sort_turbulence                                        10.764286
# injury_severity_turbulence                                      9.979978
# combo_turbulence                                               10.317975
# patient_sort_entropy                                            0.971307
# injury_severity_entropy                                         0.992215
# combo_entropy                                                   0.933817
# patient_sort_complexity                                         0.594684
# injury_severity_complexity                                      0.671994
# combo_complexity                                                0.580348
# first_engagement                                                474143.0
# first_treatment                                                 495969.0
# injury_correctly_treated_count                                         7
# injury_not_treated_count                                               3
# injury_wrongly_treated_count                                           2
# is_a_one_triage_file                                                True
# is_scene_aborted                                                   False
# last_engagement                                                1044978.0
# logger_version                                                       1.0
# percent_hemorrhage_controlled                                  44.444444
# pulse_taken_count                                                     42
# scene_end                                                        1053515
# scene_start                                                       417044
# scene_type                                                        Triage
# stills_value                                                           1
# teleport_count                                                        63
# time_to_last_hemorrhage_controlled                                405716
# total_actions                                                       1251
# triage_time                                                       636471
# voice_capture_count                                                   23
# walk_command_count                                                     1
# walk_value                                                             1
# walkers_value                                                          0
# wave_command_count                                                     1
# wave_value                                                             1
# is_cluster2                                                        False
# injury_treatments_count                                              9.0
# file_name                                         v.1.0/Clean Marty7.csv
# session_file_date                                    2023-03-03 12:31:00
# responder_name                                                  Robert R
# responder_type                                                 Paramedic
# site_name                                                   Union County
# encounter_layout                                                First 11
# session_file_week                                                 202309
# session_file_week_category                                           0.0
#
#                                                                      773  \
# session_uuid                        e3c2b4c6-d8b7-4b64-8cd0-7ca0e622f9b5
# scene_id                                                               1
# last_still_engagement                                           285708.0
# actual_engagement_distance                                     39.818552
# ideal_engagement_distance                                      41.213144
# measure_of_ideal_ordering                                       0.542837
# distracted_engagement_distance                                 31.312498
# measure_of_distracted_ordering                                  0.066558
# measure_of_right_ordering                                       0.886881
# actual_ideal_delta                                             -1.394592
# actual_distracted_delta                                         8.506054
# adherence_to_salt                                                  False
# has_patient_in_agony                                                True
# patient_count                                                         11
# cluster_label                                                          0
# patient_sort_turbulence                                         9.971331
# injury_severity_turbulence                                      9.526787
# combo_turbulence                                               10.012214
# patient_sort_entropy                                            0.971307
# injury_severity_entropy                                         0.992215
# combo_entropy                                                   0.933817
# patient_sort_complexity                                         0.594684
# injury_severity_complexity                                      0.736133
# combo_complexity                                                0.635739
# first_engagement                                                348803.0
# first_treatment                                                 440507.0
# injury_correctly_treated_count                                         9
# injury_not_treated_count                                               0
# injury_wrongly_treated_count                                           0
# is_a_one_triage_file                                                True
# is_scene_aborted                                                   False
# last_engagement                                                 741321.0
# logger_version                                                       1.0
# percent_hemorrhage_controlled                                  55.555556
# pulse_taken_count                                                     16
# scene_end                                                         771104
# scene_start                                                       252268
# scene_type                                                        Triage
# stills_value                                                           0
# teleport_count                                                        76
# time_to_last_hemorrhage_controlled                                316099
# total_actions                                                        367
# triage_time                                                       518836
# voice_capture_count                                                   84
# walk_command_count                                                     2
# walk_value                                                             1
# walkers_value                                                          1
# wave_command_count                                                     2
# wave_value                                                             1
# is_cluster2                                                        False
# injury_treatments_count                                              9.0
# file_name                                        v.1.0/Clean Marty20.csv
# session_file_date                                    2023-03-07 13:42:00
# responder_name                                                    Nick A
# responder_type                                                 Paramedic
# site_name                                                   Union County
# encounter_layout                                                First 11
# session_file_week                                                 202310
# session_file_week_category                                           9.0
#
#                                                                      465  \
# session_uuid                        851741c0-56b3-4702-8fd2-c946376840fc
# scene_id                                                               0
# last_still_engagement                                           320116.0
# actual_engagement_distance                                     31.995616
# ideal_engagement_distance                                       28.18781
# measure_of_ideal_ordering                                       0.165626
# distracted_engagement_distance                                 28.419093
# measure_of_distracted_ordering                                  0.012796
# measure_of_right_ordering                                       0.411566
# actual_ideal_delta                                              3.807806
# actual_distracted_delta                                         3.576523
# adherence_to_salt                                                  False
# has_patient_in_agony                                                True
# patient_count                                                         11
# cluster_label                                                          0
# patient_sort_turbulence                                        10.076816
# injury_severity_turbulence                                      9.430453
# combo_turbulence                                                 9.60733
# patient_sort_entropy                                            0.937231
# injury_severity_entropy                                          0.96023
# combo_entropy                                                    0.92322
# patient_sort_complexity                                         0.435406
# injury_severity_complexity                                      0.623267
# combo_complexity                                                0.544043
# first_engagement                                                 55099.0
# first_treatment                                                  63750.0
# injury_correctly_treated_count                                         3
# injury_not_treated_count                                               5
# injury_wrongly_treated_count                                           1
# is_a_one_triage_file                                                True
# is_scene_aborted                                                   False
# last_engagement                                                 529371.0
# logger_version                                                       1.3
# percent_hemorrhage_controlled                                       25.0
# pulse_taken_count                                                     32
# scene_end                                                         550665
# scene_start                                                         4149
# scene_type                                                        Triage
# stills_value                                                           0
# teleport_count                                                        24
# time_to_last_hemorrhage_controlled                                193646
# total_actions                                                        716
# triage_time                                                       546516
# voice_capture_count                                                  101
# walk_command_count                                                     2
# walk_value                                                             1
# walkers_value                                                          1
# wave_command_count                                                     8
# wave_value                                                             1
# is_cluster2                                                        False
# injury_treatments_count                                              4.0
# file_name                                   Disaster Day 2022/IP_236.csv
# session_file_date                                    2022-03-15 00:00:00
# responder_name                                                       NaN
# responder_type                                                   Unknown
# site_name                                                        Unknown
# encounter_layout                                                 Unknown
# session_file_week                                                    NaN
# session_file_week_category                                           NaN
#
#                                                                                   24   \
# session_uuid                                     06574b6f-ab02-432c-9a65-7b031218a270
# scene_id                                                                            6
# last_still_engagement                                                         71063.0
# actual_engagement_distance                                                  44.717283
# ideal_engagement_distance                                                   41.457958
# measure_of_ideal_ordering                                                    0.676695
# distracted_engagement_distance                                              30.959859
# measure_of_distracted_ordering                                               0.302423
# measure_of_right_ordering                                                         1.0
# actual_ideal_delta                                                           3.259325
# actual_distracted_delta                                                     13.757424
# adherence_to_salt                                                                True
# has_patient_in_agony                                                             True
# patient_count                                                                      11
# cluster_label                                                                       0
# patient_sort_turbulence                                                      11.53472
# injury_severity_turbulence                                                  10.330917
# combo_turbulence                                                            10.507795
# patient_sort_entropy                                                         0.971307
# injury_severity_entropy                                                      0.992215
# combo_entropy                                                                0.933817
# patient_sort_complexity                                                      0.420505
# injury_severity_complexity                                                    0.60105
# combo_complexity                                                             0.519079
# first_engagement                                                            1969241.0
# first_treatment                                                             1976493.0
# injury_correctly_treated_count                                                      8
# injury_not_treated_count                                                            1
# injury_wrongly_treated_count                                                        1
# is_a_one_triage_file                                                            False
# is_scene_aborted                                                                False
# last_engagement                                                             2229630.0
# logger_version                                                                    1.0
# percent_hemorrhage_controlled                                               55.555556
# pulse_taken_count                                                                  14
# scene_end                                                                     2279629
# scene_start                                                                   1934866
# scene_type                                                                     Triage
# stills_value                                                                        1
# teleport_count                                                                     57
# time_to_last_hemorrhage_controlled                                             205328
# total_actions                                                                     535
# triage_time                                                                    344763
# voice_capture_count                                                                19
# walk_command_count                                                                  2
# walk_value                                                                          1
# walkers_value                                                                       1
# wave_command_count                                                                  2
# wave_value                                                                          1
# is_cluster2                                                                     False
# injury_treatments_count                                                           9.0
# file_name                           v.1.0/Clean 06574b6f-ab02-432c-9a65-7b031218a2...
# session_file_date                                                 2023-05-16 00:00:00
# responder_name                                                                    NaN
# responder_type                                                                Unknown
# site_name                                                                     Unknown
# encounter_layout                                                              Unknown
# session_file_week                                                                 NaN
# session_file_week_category                                                        NaN
#
#                                                                                 379  \
# session_uuid                                   6b704e43-9ef4-4d5c-b39b-40c41648f8d3
# scene_id                                                                          1
# last_still_engagement                                                      143923.0
# actual_engagement_distance                                                40.338421
# ideal_engagement_distance                                                 40.998302
# measure_of_ideal_ordering                                                  0.697932
# distracted_engagement_distance                                            30.075073
# measure_of_distracted_ordering                                             0.252135
# measure_of_right_ordering                                                  0.999171
# actual_ideal_delta                                                        -0.659881
# actual_distracted_delta                                                   10.263348
# adherence_to_salt                                                             False
# has_patient_in_agony                                                           True
# patient_count                                                                    11
# cluster_label                                                                     0
# patient_sort_turbulence                                                    9.759827
# injury_severity_turbulence                                                 9.397504
# combo_turbulence                                                           9.755056
# patient_sort_entropy                                                       0.971307
# injury_severity_entropy                                                    0.992215
# combo_entropy                                                              0.933817
# patient_sort_complexity                                                    0.594684
# injury_severity_complexity                                                 0.736133
# combo_complexity                                                           0.635739
# first_engagement                                                           352696.0
# first_treatment                                                            383414.0
# injury_correctly_treated_count                                                    6
# injury_not_treated_count                                                          2
# injury_wrongly_treated_count                                                      2
# is_a_one_triage_file                                                           True
# is_scene_aborted                                                              False
# last_engagement                                                            761380.0
# logger_version                                                                  1.3
# percent_hemorrhage_controlled                                             55.555556
# pulse_taken_count                                                                11
# scene_end                                                                    791870
# scene_start                                                                  298278
# scene_type                                                                   Triage
# stills_value                                                                      0
# teleport_count                                                                   22
# time_to_last_hemorrhage_controlled                                           295262
# total_actions                                                                   830
# triage_time                                                                  493592
# voice_capture_count                                                              83
# walk_command_count                                                                6
# walk_value                                                                        1
# walkers_value                                                                     1
# wave_command_count                                                                9
# wave_value                                                                        1
# is_cluster2                                                                   False
# injury_treatments_count                                                         8.0
# file_name                           All CSV files renamed by date/03.14.23.1554.csv
# session_file_date                                               2023-03-14 15:53:51
# responder_name                                                            Heather W
# responder_type                                                              M4-ATEM
# site_name                                                                    OSUCOM
# encounter_layout                                                           First 11
# session_file_week                                                            202311
# session_file_week_category                                                      6.0
#
#                                                                                   22
# session_uuid                                     06574b6f-ab02-432c-9a65-7b031218a270
# scene_id                                                                            4
# last_still_engagement                                                         63905.0
# actual_engagement_distance                                                  34.253458
# ideal_engagement_distance                                                   41.544918
# measure_of_ideal_ordering                                                    0.444308
# distracted_engagement_distance                                              32.000526
# measure_of_distracted_ordering                                               0.103636
# measure_of_right_ordering                                                    0.731201
# actual_ideal_delta                                                           -7.29146
# actual_distracted_delta                                                      2.252932
# adherence_to_salt                                                               False
# has_patient_in_agony                                                             True
# patient_count                                                                      11
# cluster_label                                                                       0
# patient_sort_turbulence                                                      10.10083
# injury_severity_turbulence                                                  10.174065
# combo_turbulence                                                            10.262121
# patient_sort_entropy                                                         0.971307
# injury_severity_entropy                                                      0.992215
# combo_entropy                                                                0.933817
# patient_sort_complexity                                                      0.515011
# injury_severity_complexity                                                   0.671994
# combo_complexity                                                             0.580348
# first_engagement                                                            1291142.0
# first_treatment                                                             1299567.0
# injury_correctly_treated_count                                                      6
# injury_not_treated_count                                                            2
# injury_wrongly_treated_count                                                        0
# is_a_one_triage_file                                                            False
# is_scene_aborted                                                                False
# last_engagement                                                             1545543.0
# logger_version                                                                    1.0
# percent_hemorrhage_controlled                                               55.555556
# pulse_taken_count                                                                  30
# scene_end                                                                     1566855
# scene_start                                                                   1265396
# scene_type                                                                     Triage
# stills_value                                                                        1
# teleport_count                                                                     59
# time_to_last_hemorrhage_controlled                                             199540
# total_actions                                                                     512
# triage_time                                                                    301459
# voice_capture_count                                                                40
# walk_command_count                                                                  3
# walk_value                                                                          1
# walkers_value                                                                       0
# wave_command_count                                                                  7
# wave_value                                                                          1
# is_cluster2                                                                     False
# injury_treatments_count                                                           6.0
# file_name                           v.1.0/Clean 06574b6f-ab02-432c-9a65-7b031218a2...
# session_file_date                                                 2023-05-16 00:00:00
# responder_name                                                                    NaN
# responder_type                                                                Unknown
# site_name                                                                     Unknown
# encounter_layout                                                              Unknown
# session_file_week                                                                 NaN
# session_file_week_category                                                        NaN
