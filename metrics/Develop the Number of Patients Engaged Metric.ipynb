# %%
# %pprint
import sys
sys.path.insert(1, '../py')
# Out:
# Pretty printing has been turned OFF

# %%
import os
from pandas import DataFrame
import pandas as pd
from notebook_utils import NotebookUtilities
import matplotlib.pyplot as plt
import re
import humanize
from datetime import timedelta

nu = NotebookUtilities(data_folder_path=os.path.abspath('../data'))

# %%
# Get all CSVs into one data frame
if nu.pickle_exists('frvrs_logs_df'):
    frvrs_logs_df = nu.load_object('frvrs_logs_df')
    print(frvrs_logs_df.shape)
    # df = frvrs_logs_df.sample(4).dropna(axis='columns', how='all')
    # display(df.T)
# Out:
# (842663, 112)

# %% [markdown]
# # Number of Patients Engaged

# %%
# Number of patients engaged
if nu.pickle_exists('percentage_engaged_df'):
    percentage_engaged_df = nu.load_object('percentage_engaged_df')
else:
    
    # Initialize an empty list to store the data for each session
    rows_list = []
    
    # Loop through each unique UUID and scene combination
    for (session_uuid, scene_index), scene_df in fu.get_session_groupby(extra_column='scene_index'):
        
        # Get the logger version and scene categories
        logger_version = fu.get_logger_version(scene_df)
        is_scene_aborted = fu.get_is_scene_aborted(scene_df)
        scene_type = fu.get_scene_type(scene_df)
    
        # Get the number of patients in the group
        patients_count = fu.get_patient_count(scene_df)
    
        # Initialize a counter for patients engaged in the current group
        patients_engaged = 0
        
        # Loop through each unique patient_id in the current group
        for patient_id, patient_df in scene_df.groupby('patient_id'):
            
            # Create a mask to filter rows where action_type is 'PATIENT_ENGAGED'
            mask_series = (patient_df.action_type == 'PATIENT_ENGAGED')
            
            # If the filtered dataframe has any rows, increment the number of patients engaged
            if patient_df[mask_series].shape[0]: patients_engaged += 1
    
        # If there are any patients in the group, add a row to the results list with the following information:
        # * logger version
        # * session uuid
        # * scene
        # * number of patients in the group
        # * number of patients engaged in the group
        # * percentage of patients engaged in the group
        if patients_count:
            
            # Create a dictionary to store the data for the current group
            row_dict = {}
            for cn in fu.scene_groupby_columns: row_dict[cn] = eval(cn)
            row_dict['logger_version'] = logger_version
            row_dict['is_scene_aborted'] = is_scene_aborted
            row_dict['scene_type'] = scene_type
            row_dict['patients_count'] = patients_count
            row_dict['patients_engaged'] = patients_engaged
            row_dict['percentage_engaged'] = patients_engaged / patients_count
            
            # Append the dictionary to the list of rows
            rows_list.append(row_dict)
    
    # Create a data frame from the list of dictionaries
    percentage_engaged_df = DataFrame(rows_list)
    nu.store_objects(percentage_engaged_df=percentage_engaged_df)
# Out:
# Pickling to C:\Users\DaveBabbitt\Documents\GitHub\itm-analysis-reporting\saves\pkl\percentage_engaged_df.pkl

# %%
# Get average number of patients engaged (this could be including the ones that wave, walk, put hands up)
mask_series = (percentage_engaged_df.scene_type == 'Triage') & (percentage_engaged_df.is_scene_aborted == False)
ave_patients_engaged = percentage_engaged_df[mask_series].patients_engaged.mean()
print(f'The average number of patients engaged per scene is {ave_patients_engaged:0.2}.')
# Out:
# The average number of patients engaged per scene is 5.9.

# %%
# Get scene with the most ignored patients, v1.3
mask_series = (percentage_engaged_df.percentage_engaged == 0) & (percentage_engaged_df.logger_version == 1.3)
fu.visualize_extreme_player_movement(
    percentage_engaged_df, 'patients_count', mask_series=mask_series, is_ascending=False, humanize_type='intword',
    title_str='most ignored patients', frvrs_logs_df=frvrs_logs_df, verbose=False
)

# %%
# Get scene with the most ignored patients, v1.0
mask_series = (percentage_engaged_df.percentage_engaged == 0) & (percentage_engaged_df.logger_version == 1.0)
fu.visualize_extreme_player_movement(
    percentage_engaged_df, 'patients_count', mask_series=mask_series, is_ascending=False, humanize_type='intword',
    title_str='most ignored patients', frvrs_logs_df=frvrs_logs_df, verbose=False
)

# %%
# Get scene with the least ignored patients, v1.3
mask_series = (percentage_engaged_df.logger_version == 1.3)
df = percentage_engaged_df[mask_series].sort_values(['percentage_engaged', 'patients_count']).tail(1)
patients_session_uuid = df.session_uuid.squeeze()
patients_time_group = df.scene_index.squeeze()
base_mask_series = (frvrs_logs_df.session_uuid == patients_session_uuid) & (frvrs_logs_df.scene_index == patients_time_group)

title = f'Location Map for UUID {patients_session_uuid} ({humanize.ordinal(patients_time_group+1)} Session)'
title += ' showing Trainee with the Least Ignored Patients'
fu.visualize_player_movement(base_mask_series, title=title, frvrs_logs_df=frvrs_logs_df)

# %%
# Get scene with the least ignored patients, v1.0
mask_series = (percentage_engaged_df.logger_version == 1.0)
df = percentage_engaged_df[mask_series].sort_values(['percentage_engaged', 'patients_count']).tail(1)
patients_session_uuid = df.session_uuid.squeeze()
patients_time_group = df.scene_index.squeeze()
base_mask_series = (frvrs_logs_df.session_uuid == patients_session_uuid) & (frvrs_logs_df.scene_index == patients_time_group)

title = f'Location Map for UUID {patients_session_uuid} ({humanize.ordinal(patients_time_group+1)} Session)'
title += ' showing Trainee with the Least Ignored Patients'
fu.visualize_player_movement(base_mask_series, title=title, frvrs_logs_df=frvrs_logs_df)

# %% [markdown]
# ## How many patients are treated between the walk and wave commands?

# %%
mask_series = frvrs_logs_df.voice_command_command_description.map(
    lambda x: ('walk' in str(x).lower()) or ('wave' in str(x).lower())
)
frvrs_logs_df[mask_series].voice_command_command_description.unique().tolist()[:10]
# Out:
# ['so you know i would walk in see those four patients i would go and say if anybody can hear me i want you to WLK over here OK', "you use your your global sort commands and then then you'll teleport so go ahead and do that WAVE command OK everybody can hear me wave", 'wave', 'alright everybody can hear me walk this way', 'walk', 'two walkers everybody can hear me wave', "if anybody can walk i want you to walk over here and then once your walkers are out of the way then you're gonna go and say if anyone can wave i want you to wave and then you're gonna know who your patients are that can't follow commands OK if in real life if you come up to somebody that had a complete amputation", 'anybody that can walk walk over here', 'anybody that can wave wave', '15 minutes away OK anybody that can hear me and stand up and walk come over here']

# %%
# Display a sample of the data frame, dropping columns with all NaN values and transposing it
mask_series = frvrs_logs_df.voice_command_command_description.isin(['walk', 'wave'])
df = frvrs_logs_df[mask_series]
display(df.sample(min(4, df.shape[0])).dropna(axis='columns', how='all').T)
# Out:
#                                                                             52292   \
# action_type                                                          VOICE_COMMAND
# action_tick                                                                364660
# event_time                                                     2023-03-15 08:27:57
# session_uuid                                  b05e5139-6dd4-41d2-adb5-aedfebb028a6
# file_name                          All CSV files renamed by date/03.15.23.0843.csv
# logger_version                                                                 1.3
# scene_index                                                                       2
# voice_command_message                                              wave if you can
# voice_command_command_description                                             wave
#
#                                                                             106951  \
# action_type                                                          VOICE_COMMAND
# action_tick                                                                294969
# event_time                                                     2023-04-25 10:01:03
# session_uuid                                  89ec8f32-0018-48e7-8cad-c86bd73257f2
# file_name                          All CSV files renamed by date/04.25.23.0956.csv
# logger_version                                                                 1.3
# scene_index                                                                       2
# voice_command_message                                              wave if you can
# voice_command_command_description                                             wave
#
#                                                                  716079  \
# action_type                                               VOICE_COMMAND
# action_tick                                                      18659
# event_time                                          2023-03-03 11:03:00
# session_uuid                       d4f8b28e-a0a3-4969-a156-5bf86e4794ba
# file_name                                        v.1.0/Clean Marty3.csv
# logger_version                                                      1.0
# scene_index                                                            1
# voice_command_message                             walk to the safe area
# voice_command_command_description                                  walk
#
#                                                                             77201
# action_type                                                          VOICE_COMMAND
# action_tick                                                                568574
# event_time                                                     2023-04-19 13:06:10
# session_uuid                                  79426650-c950-40ee-816e-decddddd22e9
# file_name                          All CSV files renamed by date/04.19.23.1310.csv
# logger_version                                                                 1.3
# scene_index                                                                       2
# voice_command_message                                              wave if you can
# voice_command_command_description                                             wave

# %%
actions_list = [
    'wave if you can', 'wave if you can', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'walk to the safe area',
    'PATIENT_ENGAGED', 'walk to the safe area', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'walk to the safe area',
    'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED',
    'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'walk to the safe area', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED',
    'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED',
    'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED', 'PATIENT_ENGAGED',
    'PATIENT_ENGAGED', 'PATIENT_ENGAGED'
]
result = fu.replace_consecutive_elements(actions_list, element='PATIENT_ENGAGED')
if result != [
    'wave if you can', 'wave if you can', 'PATIENT_ENGAGED x3', 'walk to the safe area', 'PATIENT_ENGAGED x1',
    'walk to the safe area', 'PATIENT_ENGAGED x2', 'walk to the safe area', 'PATIENT_ENGAGED x9', 'walk to the safe area',
    'PATIENT_ENGAGED x16'
]:
    print('Fix first test')
    print(result)
actions_list = ['PATIENT_ENGAGED', 'wave if you can', 'wave if you can', 'walk to the safe area']
result = fu.replace_consecutive_elements(actions_list, element='PATIENT_ENGAGED')
if result != [
    'PATIENT_ENGAGED x1', 'wave if you can', 'wave if you can', 'walk to the safe area'
]:
    print('Fix second test')
    print(result)

# %%
# Visualize the number of patients engaged between walk and wave
columns_list = ['voice_command_message', 'action_type']

# Loop through each unique UUID and scene combination
for (session_uuid, scene_index), scene_df in fu.get_session_groupby(extra_column='scene_index'):
    
    # Get all the engaged, walk, and wave events in this scene
    mask_series = scene_df.voice_command_message.isin(['walk to the safe area', 'wave if you can'])
    mask_series |= (scene_df.action_type == 'PATIENT_ENGAGED')
    
    # Print out the results
    df2 = scene_df[mask_series][columns_list]#.sort_values('action_tick')
    if df2.shape[0]:
        print(session_uuid, scene_index, end=':\n', flush=True)
        actions_list = []
        for row_index, row_series in df2.iterrows():
            action_type = row_series.action_type
            if (action_type == 'PATIENT_ENGAGED'): actions_list.append('PATIENT_ENGAGED')
            else: actions_list.append(row_series.voice_command_message)
        actions_list = fu.replace_consecutive_elements(actions_list, element='PATIENT_ENGAGED')
        actions_list = fu.replace_consecutive_elements(actions_list, element='walk to the safe area')
        actions_list = fu.replace_consecutive_elements(actions_list, element='wave if you can')
        for action in actions_list:
            print('\t' + str(action))
# Out:
# 009b848c-ea64-4f22-bd40-711213a3d327 1:
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	walk to the safe area x1
# 009b848c-ea64-4f22-bd40-711213a3d327 2:
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x16
# 00b2e9d8-c3bb-4d89-92c1-abce5c4a0655 1:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 00b2e9d8-c3bb-4d89-92c1-abce5c4a0655 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# 02f6a42e-5211-40ea-8384-824a83ab6760 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x9
# 03b398c5-6fc8-459c-9662-ce1e0babe4b1 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 040ba585-ccae-45ef-b4bd-a0e35ec222b0 0:
# 	wave if you can x1
# 	walk to the safe area x1
# 040ba585-ccae-45ef-b4bd-a0e35ec222b0 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x8
# 040ba585-ccae-45ef-b4bd-a0e35ec222b0 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x6
# 04882754-51a0-4e5b-9617-b200e3609116 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 04882754-51a0-4e5b-9617-b200e3609116 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x9
# 04acc8f2-1e64-47b2-9606-8d661f584aec 0:
# 	walk to the safe area x1
# 04acc8f2-1e64-47b2-9606-8d661f584aec 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x8
# 04acc8f2-1e64-47b2-9606-8d661f584aec 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x14
# 054918a7-9634-40fe-8356-2ce0c9cc376f 1:
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x17
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x15
# 06303b89-128e-4bfb-9e6f-a843da3134f9 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x51
# 06303b89-128e-4bfb-9e6f-a843da3134f9 2:
# 	walk to the safe area x6
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# 	wave if you can x1
# 06574b6f-ab02-432c-9a65-7b031218a270 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 06574b6f-ab02-432c-9a65-7b031218a270 2:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# 06574b6f-ab02-432c-9a65-7b031218a270 3:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x6
# 06574b6f-ab02-432c-9a65-7b031218a270 5:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# 06574b6f-ab02-432c-9a65-7b031218a270 6:
# 	walk to the safe area x3
# 	wave if you can x4
# 	PATIENT_ENGAGED x4
# 06574b6f-ab02-432c-9a65-7b031218a270 7:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x13
# 06574b6f-ab02-432c-9a65-7b031218a270 9:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 06574b6f-ab02-432c-9a65-7b031218a270 10:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x14
# 	walk to the safe area x1
# 06574b6f-ab02-432c-9a65-7b031218a270 11:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x18
# 06574b6f-ab02-432c-9a65-7b031218a270 12:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x12
# 0667e56a-abe6-4097-9a56-33735f4855e2 1:
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	walk to the safe area x2
# 0667e56a-abe6-4097-9a56-33735f4855e2 2:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# 0786a1df-d010-4b1b-a99a-e00df486d479 1:
# 	wave if you can x2
# 	walk to the safe area x2
# 	wave if you can x1
# 	walk to the safe area x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x13
# 09024025-1320-4891-aefa-a497744ed3e2 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x15
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 090d0988-3f81-4603-87e2-477538a6750c 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 090d0988-3f81-4603-87e2-477538a6750c 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x15
# 0940a9be-3ff5-4739-b04b-a7605c1ffa2f 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x16
# 0950437e-94b0-45bf-8d11-dd446fd0e4a2 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
#
2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x8
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 16373b36-886a-4d0d-9015-474d29d139cc 1:
# 	PATIENT_ENGAGED x1
# 16373b36-886a-4d0d-9015-474d29d139cc 2:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x14
# 1663640c-5a60-4fa6-8bf4-249f41a693a5 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 1663640c-5a60-4fa6-8bf4-249f41a693a5 2:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# 17962d45-8e90-4b50-86e7-77451042aac8 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 17b80e0f-9afe-497f-b3a3-0549c14a4ba9 0:
# 	PATIENT_ENGAGED x1
# 17b80e0f-9afe-497f-b3a3-0549c14a4ba9 1:
# 	walk to the safe area x4
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# 1813599d-cfde-45f0-8555-428b57478ebb 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x11
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x5
# 18bfbc11-3c60-4c89-94cc-ac8fea028318 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x14
# 18e1dec6-b780-4e77-a6b9-f608f2483e53 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# 1cfebb9a-6000-4742-81be-6103ebe168bc 0:
# 	walk to the safe area x3
# 1cfebb9a-6000-4742-81be-6103ebe168bc 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 1cfebb9a-6000-4742-81be-6103ebe168bc 2:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x21
# 1df10bfd-0f85-42ff-a873-36dfe05df77b 0:
# 	walk to the safe area x1
# 1df10bfd-0f85-42ff-a873-36dfe05df77b 2:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 1df10bfd-0f85-42ff-a873-36dfe05df77b 3:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x6
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x13
# 1e7d274d-f393-4888-9f28-4de53b0260e3 1:
# 	walk to the safe area x3
# 	wave if you can x2
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x3
# 1e7d274d-f393-4888-9f28-4de53b0260e3 3:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x5
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# 1fb559e8-15c6-463a-bda8-79ca0bfc330f 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 1fb559e8-15c6-463a-bda8-79ca0bfc330f 2:
# 	walk to the safe area x2
# 	wave if you can x5
# 	PATIENT_ENGAGED x14
# 20168f93-040c-4290-aa7e-2b197825c9de 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	walk to the safe area x1
# 20168f93-040c-4290-aa7e-2b197825c9de 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x8
# 206da802-d38f-4f3a-98e3-44f99481479d 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x5
# 206da802-d38f-4f3a-98e3-44f99481479d 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x15
# 20e5782a-d6f7-4361-a590-7e710c176765 1:
# 	walk to the safe area x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 2107820d-d55c-40bb-bb90-6b10c227664c 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x3
# 2107820d-d55c-40bb-bb90-6b10c227664c 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# 21526c63-79bb-4c7b-87c2-9e7525d8515f 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x13
# 21577c78-0085-4962-a363-b88526e3c212 0:
# 	PATIENT_ENGAGED x1
# 21577c78-0085-4962-a363-b88526e3c212 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 21b0f09b-03b4-4af8-ac65-11ab1e5458d8 0:
# 	PATIENT_ENGAGED x1
# 21b0f09b-03b4-4af8-ac65-11ab1e5458d8 1:
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 21b0f09b-03b4-4af8-ac65-11ab1e5458d8 2:
# 	wave if you can x1
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 2270eaba-f9b5-4f96-8a5e-b69276846474 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x4
# 	PATIENT_ENGAGED x5
# 	wave if you can x1
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 22e2c9a3-b93f-4f7f-896a-ca188c78505b 1:
# 	PATIENT_ENGAGED x1
# 22e2c9a3-b93f-4f7f-896a-ca188c78505b 2:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x12
# 2310f107-d9d2-418e-a2d7-dd7a17924544 1:
# 	walk to the safe area x1
# 24205a11-9e21-44b7-a565-985454c90776 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 24205a11-9e21-44b7-a565-985454c90776 2:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x18
# 251a4532-ff1f-4182-91ce-4215786a339a 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# 25309ebf-8ca2-4678-af43-2d4030eb1c5d 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 25309ebf-8ca2-4678-af43-2d4030eb1c5d 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED
1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# 4226ad6c-bb0a-4df0-8c4a-64c312927578 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 4226ad6c-bb0a-4df0-8c4a-64c312927578 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x11
# 43313faf-6031-4433-be70-d5d828f55cff 0:
# 	walk to the safe area x1
# 43313faf-6031-4433-be70-d5d828f55cff 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 43313faf-6031-4433-be70-d5d828f55cff 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# 433e6561-c9cd-48c8-91a8-0318e656996f 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x2
# 433e6561-c9cd-48c8-91a8-0318e656996f 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x10
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# 43ce12a6-e8c6-446c-bc3a-1b8820b9490f 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x3
# 44458d4a-3cce-4907-85e3-3db1375ce6bb 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x8
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x14
# 445ceb23-1514-4490-9aa6-f2fc55b5d28e 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x16
# 45118b95-412c-4a2d-9373-8f7da3428ca8 1:
# 	walk to the safe area x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 45118b95-412c-4a2d-9373-8f7da3428ca8 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x12
# 46c273a6-b8be-46ea-96cd-72903780d43d 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x2
# 46c273a6-b8be-46ea-96cd-72903780d43d 2:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x43
# 4727e60f-7e08-4595-b565-b6e80b7a8d87 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 47bb9911-6096-4703-8551-4a0f8cb1063a 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 47bb9911-6096-4703-8551-4a0f8cb1063a 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# 48c426ae-e88c-49bd-8010-37dc7b042c95 1:
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x12
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 48e95cfe-1dd7-4085-9662-c77827980bdd 0:
# 	walk to the safe area x1
# 	wave if you can x1
# 48e95cfe-1dd7-4085-9662-c77827980bdd 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 48e95cfe-1dd7-4085-9662-c77827980bdd 3:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x16
# 496ff2bf-605d-4654-b945-dc2b0aaea626 0:
# 	PATIENT_ENGAGED x1
# 496ff2bf-605d-4654-b945-dc2b0aaea626 1:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x15
# 4a219569-77fc-41c2-8244-42888b25fec3 1:
# 	PATIENT_ENGAGED x5
# 4a504e80-0232-4978-9a63-7e503e86c5e3 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 4bac0722-bc76-4418-88f0-ccbbba469c5a 0:
# 	PATIENT_ENGAGED x1
# 4bac0722-bc76-4418-88f0-ccbbba469c5a 1:
# 	walk to the safe area x1
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x1
# 4bac0722-bc76-4418-88f0-ccbbba469c5a 2:
# 	walk to the safe area x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	wave if you can x3
# 	PATIENT_ENGAGED x10
# 4ca5febe-0a4b-4c77-bd3e-6632ae760df1 1:
# 	PATIENT_ENGAGED x1
# 4ca5febe-0a4b-4c77-bd3e-6632ae760df1 2:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x21
# 4ce8ee9f-45ea-42a8-86df-0038c777f040 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 	wave if you can x2
# 	PATIENT_ENGAGED x6
# 4f66ee10-3104-44ec-8d31-9e1c2b33f36d 1:
# 	wave if you can x2
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x14
# 50e4351a-3afd-43ff-a65f-f84eaab0d0fd 0:
# 	walk to the safe area x1
# 50e4351a-3afd-43ff-a65f-f84eaab0d0fd 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 50e4351a-3afd-43ff-a65f-f84eaab0d0fd 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x9
# 51f8d40c-9550-4ef1-a71c-e030c0a08f29 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# 51f8d40c-9550-4ef1-a71c-e030c0a08f29 2:
# 	walk to the safe area x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x11
# 524d5418-62f4-4834-9f1e-47202c30e667 1:
# 	walk to the safe area x3
# 	wave if you can x8
# 	PATIENT_ENGAGED x4
# 524d5418-62f4-4834-9f1e-47202c30e667 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# 5254234d-5334-44d0-a97b-d0e098c129a9 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x5
# 5254234d-5334-44d0-a97b-d0e098c129a9 2:
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
#

# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x12
# 724fdf45-3165-43b8-b9ca-dc07102d2886 6:
# 	walk to the safe area x2
# 	wave if you can x4
# 	PATIENT_ENGAGED x3
# 724fdf45-3165-43b8-b9ca-dc07102d2886 7:
# 	walk to the safe area x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# ...
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# de04bec3-9503-467c-9c49-675720c4bab0 3:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x9
# de327503-2f08-4562-9543-547cbabd52e1 1:
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# dee5a112-91db-43bb-8564-dc4ce4195a88 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x11
# deecd930-56c6-4679-87d8-7d6627631934 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x7
# deecd930-56c6-4679-87d8-7d6627631934 2:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x17
# dfa09c43-42f4-4cb5-8f74-381744e0d320 1:
# 	walk to the safe area x4
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x11
# dfd3aa1c-7b73-43a7-80c0-80beeabcd985 1:
# 	walk to the safe area x1
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# dfd3aa1c-7b73-43a7-80c0-80beeabcd985 2:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# e072d31f-2592-4c7e-8709-3db1e111240c 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# e072d31f-2592-4c7e-8709-3db1e111240c 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# e0b7bea0-1cf9-42a8-a02c-e8699a962779 0:
# 	PATIENT_ENGAGED x1
# e0b7bea0-1cf9-42a8-a02c-e8699a962779 1:
# 	walk to the safe area x1
# 	wave if you can x5
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x7
# e1a418bf-114d-4b8e-b0a1-0a0ff144c0aa 0:
# 	PATIENT_ENGAGED x1
# e1a418bf-114d-4b8e-b0a1-0a0ff144c0aa 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# e1a418bf-114d-4b8e-b0a1-0a0ff144c0aa 2:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x10
# e1d845d3-9874-449b-83ef-6c649073a868 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# e1d845d3-9874-449b-83ef-6c649073a868 2:
# 	walk to the safe area x3
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x7
# e2458ea2-71b5-4b84-bbfb-dff0a969c9d2 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x12
# e249e6d4-c3d4-4e20-8fab-fa35fd59e871 1:
# 	walk to the safe area x3
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x7
# 	wave if you can x1
# 	PATIENT_ENGAGED x27
# e2ddf563-3583-404c-917a-8eb7bec38471 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# e2ddf563-3583-404c-917a-8eb7bec38471 2:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x12
# e2e599c8-8e48-487f-9f95-a0a382432ca5 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x5
# e2e599c8-8e48-487f-9f95-a0a382432ca5 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x11
# e353eee2-a630-40cd-b931-a98b12edd9b6 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# e3c2b4c6-d8b7-4b64-8cd0-7ca0e622f9b5 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# e3c2b4c6-d8b7-4b64-8cd0-7ca0e622f9b5 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# e4b17764-a999-4733-b455-1968588effc8 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x10
# e662a811-40fd-4bf2-b9df-d2d221d07b4a 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# e662a811-40fd-4bf2-b9df-d2d221d07b4a 2:
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x14
# e77c15e0-d0de-413d-a471-20a285e81387 1:
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# e7ea73c9-dc1c-47cc-bb13-996b4069c73e 1:
# 	PATIENT_ENGAGED x7
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# e8be80d7-4d11-430d-93b7-bc15e1bfb445 1:
# 	wave if you can x2
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x13
# 	wave if you can x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# e8cb6ae0-6d68-410f-88fc-4adf30d8bfac 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# e8cb6ae0-6d68-410f-88fc-4adf30d8bfac 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x15
# e96d123b-455b-4335-9278-988ff9ba8ecf 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x5
# e96d123b-455b-4335-9278-988ff9ba8ecf 2:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x9
# e9a830dc-ee6e-458b-ad43-84ee338a9bd2 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	wave if you can x5
# 	PATIENT_ENGAGED x2
# e9a830dc-ee6e-458b-ad43-84ee338a9bd2 2:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x16
# ea7d43f6-a7ed-4bc7-8002-f056ee415082 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x21
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# eb641af4-13da-4e13-a5dd-02eb0e7e6c23 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# eb641af4-13da-4e13-a5dd-02eb0e7e6c23 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	walk to the safe area x1
# 	wave if you can x6
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x14
# ebc4fb38-01c3-4296-b22d-34adf70e0d43 1:
# 	PATIENT_ENGAGED x11
# ec6c5444-8f8b-417d-a840-f1173d3a0296 1:
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x6
# ed079161-e1ea-4682-9abb-d0b1736e3ee5 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# ee42b183-00b2-4bb9-89b9-0b38b73e69eb 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 	walk to the safe area x1
# ee42b183-00b2-4bb9-89b9-0b38b73e69eb 2:
# 	walk to the safe area x2
# 	wave if you can x4
# 	PATIENT_ENGAGED x13
# ee694b2c-dad2-4b9a-acc9-4e025e1b299b 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# ee694b2c-dad2-4b9a-acc9-4e025e1b299b 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# ee8a8276-1a9c-41fd-a793-a3eb6d337ff7 1:
# 	walk to the safe area x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# ee8a8276-1a9c-41fd-a793-a3eb6d337ff7 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# eecb1d19-1d05-4725-9289-eb02d601cdf3 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# eecb1d19-1d05-4725-9289-eb02d601cdf3 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x8
# efed5e1c-4427-47df-8e3f-9e4714880169 1:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# efed5e1c-4427-47df-8e3f-9e4714880169 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# f02dc87e-8f04-4ddd-90fd-74dce1206bd6 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# f02dc87e-8f04-4ddd-90fd-74dce1206bd6 2:
# 	walk to the safe area x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# f0a4acff-b70a-4577-a27e-df492cb9638d 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x4
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# f0a4acff-b70a-4577-a27e-df492cb9638d 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x17
# f1b2887d-8ed3-499e-8663-0fb9bd909fbc 1:
# 	walk to the safe area x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# 	walk to the safe area x1
# f1b2887d-8ed3-499e-8663-0fb9bd909fbc 2:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x11
# f2eb6809-d49f-4c3e-be62-91f1538ed437 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x18
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# f3228193-b6dc-41fa-a2ab-1c5085046347 1:
# 	walk to the safe area x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# f3228193-b6dc-41fa-a2ab-1c5085046347 2:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x11
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x2
# f33f702d-4b79-43d9-b980-42dc10c2b882 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x4
# f33f702d-4b79-43d9-b980-42dc10c2b882 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x8
# f3447210-99fa-4990-8c1b-747a1e916e79 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x10
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x13
# f3cbb8a9-8d0c-48f0-ac0c-e379ac4d9411 1:
# 	walk to the safe area x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x4
# f3cbb8a9-8d0c-48f0-ac0c-e379ac4d9411 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# f5dafd5d-461d-4440-9e3b-1b1c899df9e4 1:
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x4
# f5dafd5d-461d-4440-9e3b-1b1c899df9e4 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x12
# f68ce2b4-67dc-4829-89fc-cfe478391148 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x7
# f68ce2b4-67dc-4829-89fc-cfe478391148 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x14
# f7b46b02-bc04-42d6-a3aa-abd797948735 1:
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x2
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x11
# 	walk to the safe area x1
# f7d9738a-35c1-4af0-8e98-5bf3a1cff310 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# f7d9738a-35c1-4af0-8e98-5bf3a1cff310 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x2
# 	PATIENT_ENGAGED x13
# f807c3e2-6cc7-4670-8488-4dd13431cc15 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x16
# 	walk to the safe area x1
# f80ef1e8-e0d1-4106-9f18-4024ff911e22 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x5
# f80ef1e8-e0d1-4106-9f18-4024ff911e22 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x15
# f8b5cbd1-0abe-483b-8b16-956044dc0119 1:
# 	PATIENT_ENGAGED x9
# 	walk to the safe area x1
# f90a6408-2a18-49b4-8a6b-edee48e7e9ed 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x5
# f90a6408-2a18-49b4-8a6b-edee48e7e9ed 2:
# 	walk to the safe area x2
# 	wave if you can x2
# 	PATIENT_ENGAGED x13
# f92400e2-63f5-4bb8-95b3-dcf065e17414 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# f9b3d74c-634d-40fc-9183-4c4bad4e7548 1:
# 	walk to the safe area x2
# 	wave if you can x3
# 	PATIENT_ENGAGED x12
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# fa155795-d519-45a5-89a4-0ee8c4ea756d 1:
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x3
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# fa155795-d519-45a5-89a4-0ee8c4ea756d 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# fc2ed173-5990-4461-9a20-ac856bbb946b 1:
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# fd1c7057-2c2d-4dec-9297-92ef0621c15e 1:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x30
# fd1c7057-2c2d-4dec-9297-92ef0621c15e 2:
# 	walk to the safe area x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x5
# fdb4a6d9-72ef-4af7-bdd4-a05ba354a300 1:
# 	walk to the safe area x2
# 	wave if you can x4
# 	PATIENT_ENGAGED x3
# 	wave if you can x2
# 	PATIENT_ENGAGED x12
# fde2c201-36fc-4123-bf42-f1bff1b24969 1:
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x9
# fe077b96-8e52-4e1a-8ec7-e5c5f46e65c5 1:
# 	PATIENT_ENGAGED x1
# fe077b96-8e52-4e1a-8ec7-e5c5f46e65c5 2:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x15
# fe2602f0-e9e8-4913-8bf3-806852ce738a 1:
# 	walk to the safe area x2
# 	PATIENT_ENGAGED x1
# fe2602f0-e9e8-4913-8bf3-806852ce738a 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x20
# ff4c3532-5924-45b6-9a6a-d0d3274b6ef0 1:
# 	PATIENT_ENGAGED x1
# ff4c3532-5924-45b6-9a6a-d0d3274b6ef0 2:
# 	PATIENT_ENGAGED x7
# ff97fc56-c803-4aa7-b419-35e0ac17d0b3 0:
# 	walk to the safe area x1
# ff97fc56-c803-4aa7-b419-35e0ac17d0b3 1:
# 	wave if you can x1
# 	PATIENT_ENGAGED x4
# ff97fc56-c803-4aa7-b419-35e0ac17d0b3 2:
# 	walk to the safe area x1
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x2
# 	wave if you can x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x6
# ffecd29f-ebcd-45d2-9bc1-12adf56cfff8 0:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x2
# 	wave if you can x1
# 	walk to the safe area x1
# 	wave if you can x1
# 	walk to the safe area x1
# ffecd29f-ebcd-45d2-9bc1-12adf56cfff8 1:
# 	PATIENT_ENGAGED x1
# 	walk to the safe area x3
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x2
# ffecd29f-ebcd-45d2-9bc1-12adf56cfff8 2:
# 	PATIENT_ENGAGED x3
# 	walk to the safe area x1
# 	PATIENT_ENGAGED x3
# 	wave if you can x1
# 	PATIENT_ENGAGED x11

# %% [markdown]
# ## How many times are walk / wave commands issued?

# %%
# Get the number of times walk / wave commands are issued
if nu.pickle_exists('walk_and_wave_count_df'):
    walk_and_wave_count_df = nu.load_object('walk_and_wave_count_df')
else:
    columns_list = ['voice_command_message', 'action_type']
    rows_list = []

    # Initialize the count of times between walk / wave commands
    betweens_list = []
    
    # Loop through each unique file and scene combination
    for (session_uuid, scene_index), scene_df in fu.get_session_groupby(extra_column='scene_index'):
        
        # Add the logger version and scene categories
        row_dict = {}
        row_dict['logger_version'] = fu.get_logger_version(scene_df)
        for cn in fu.scene_groupby_columns: row_dict[cn] = eval(cn)
        row_dict['is_scene_aborted'] = fu.get_is_scene_aborted(scene_df)
        row_dict['scene_type'] = fu.get_scene_type(scene_df)
        
        # Get all the walk events in this scene
        row_dict['walk_count'] = fu.get_walk_command_count(scene_df)
        
        # Get all the wave events in this scene
        row_dict['wave_count'] = fu.get_wave_command_count(scene_df)
        
        # Get all the walk and wave events in this scene
        row_dict['walk_and_wave_count'] = row_dict['walk_count'] + row_dict['wave_count']

        # Record the timestamps of each
        mask_series = scene_df.voice_command_message.isin(['walk to the safe area', 'wave if you can'])
        betweens_list.extend(scene_df[mask_series].action_tick.tolist())
    
        # Append the data row to the dataset
        rows_list.append(row_dict)
    
    walk_and_wave_count_df = DataFrame(rows_list)
    nu.store_objects(walk_and_wave_count_df=walk_and_wave_count_df)
# Out:
# Pickling to C:\Users\DaveBabbitt\Documents\GitHub\itm-analysis-reporting\saves\pkl\walk_and_wave_count_df.pkl

# %%
get_xtick_text = lambda text_obj: text_obj.get_position()[0]
xlabel = 'Count of Walk Commands Issued'
title = f'Histogram of {xlabel}'
mask_series = (walk_and_wave_count_df.scene_type == 'Triage') & (walk_and_wave_count_df.is_scene_aborted == False)
fig = nu.plot_histogram(walk_and_wave_count_df[mask_series], 'walk_count', xlabel=xlabel, xtick_text_fn=get_xtick_text, title=title)

# %%
xlabel = 'Count of Wave Commands Issued'
title = f'Histogram of {xlabel}'
mask_series = (walk_and_wave_count_df.scene_type == 'Triage') & (walk_and_wave_count_df.is_scene_aborted == False)
fig = nu.plot_histogram(walk_and_wave_count_df[mask_series], 'wave_count', xlabel=xlabel, xtick_text_fn=get_xtick_text, title=title)

# %%
xlabel = 'Count of Walk and/or Wave Commands Issued'
title = f'Histogram of {xlabel}'
mask_series = (walk_and_wave_count_df.scene_type == 'Triage') & (walk_and_wave_count_df.is_scene_aborted == False)
fig = nu.plot_histogram(walk_and_wave_count_df[mask_series], 'walk_and_wave_count', xlabel=xlabel, xtick_text_fn=get_xtick_text, title=title)

# %%
# What is the average time between walk / wave commands?
df = pd.Series(betweens_list).to_frame().rename(columns={0: 'action_tick'})
df['time_diff'] = df.action_tick.diff().map(lambda x: abs(x))
ave_time = humanize.precisedelta(timedelta(milliseconds=df.time_diff.mean()))
# print(f'The average time between walk/wave commands is {ave_time}.')
xlabel = 'Time between Walk/Wave Commands'
get_xtick_text = lambda text_obj: humanize.precisedelta(
    timedelta(milliseconds=text_obj.get_position()[0])
).replace(', ', ',\n').replace(' and ', ' and\n')
title = f'Histogram of {xlabel}'
nu.plot_histogram(df, 'time_diff', xlabel=xlabel, xtick_text_fn=get_xtick_text, title=title)
